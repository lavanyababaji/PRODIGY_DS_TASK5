# %%
import pandas as pd

# %%
file_path = 'C:/Users/lavan/Downloads/accidents.csv'
data = pd.read_csv(file_path)

# %%
data.head()
# Out:
#   AccidentDate     Timing       State WeatherCondition       RoadCondition  \
# 0   04-02-2013    Morning      Alaska            Rainy  Under Construction
# 1   23-02-2005      Night     Arizona            Clear  Under Construction
# 2   08-10-2014  Afternoon  California            Clear                Fine
# 3   14-01-2015      Night    Colorado            Rainy               Rough
# 4   17-01-2006  Afternoon     Georgia            Clear                Fine
#
#    Deaths              Reason
# 0      10       Drunk Driving
# 1       3  Weather Conditions
# 2       6     Poor Visibility
# 3       8     Road Conditions
# 4       2            Speeding

# %%
data['AccidentDate'] = pd.to_datetime(data['AccidentDate'], format='%d-%m-%Y')

# %%
missing_values = data.isnull().sum()

# %%
missing_values
# Out:
# AccidentDate        0
# Timing              0
# State               0
# WeatherCondition    0
# RoadCondition       0
# Deaths              0
# Reason              0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(15, 10))

# %%
custom_palette_weather = sns.color_palette(["#ff9999", "#66b3ff", "#99ff99", "#ffcc99"])
custom_palette_road = sns.color_palette(["#c2c2f0", "#ffb3e6", "#ff6666"])
custom_palette_timing = sns.color_palette(["#ffb347", "#ffcc99", "#c2f0c2"])

# %%
plt.subplot(2, 2, 1)
sns.countplot(data=data, x='WeatherCondition', palette=custom_palette_weather)
plt.title('Accidents by Weather Condition')
plt.xlabel('Weather Condition')
plt.ylabel('Number of Accidents')
plt.xticks(rotation=45)
# Out:
# C:\Users\lavan\AppData\Local\Temp\ipykernel_3648\487775019.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=data, x='WeatherCondition', palette=custom_palette_weather)
# C:\Users\lavan\AppData\Local\Temp\ipykernel_3648\487775019.py:2: UserWarning: The palette list has more values (4) than needed (3), which may not be intended.
#   sns.countplot(data=data, x='WeatherCondition', palette=custom_palette_weather)
# ([0, 1, 2], [Text(0, 0, 'Rainy'), Text(1, 0, 'Clear'), Text(2, 0, 'Foggy')])

# %%
plt.subplot(2, 2, 2)
sns.countplot(data=data, x='RoadCondition', palette=custom_palette_road)
plt.title('Accidents by Road Condition')
plt.xlabel('Road Condition')
plt.ylabel('Number of Accidents')
plt.xticks(rotation=45)
# Out:
# C:\Users\lavan\AppData\Local\Temp\ipykernel_3648\3509542791.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=data, x='RoadCondition', palette=custom_palette_road)
# ([0, 1, 2],
#  [Text(0, 0, 'Under Construction'), Text(1, 0, 'Fine'), Text(2, 0, 'Rough')])

# %%
plt.subplot(2, 2, 3)
sns.countplot(data=data, x='Timing', palette=custom_palette_timing)
plt.title('Accidents by Time of Day')
plt.xlabel('Time of Day')
plt.ylabel('Number of Accidents')
plt.xticks(rotation=45)
# Out:
# C:\Users\lavan\AppData\Local\Temp\ipykernel_3648\4218787735.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=data, x='Timing', palette=custom_palette_timing)
# C:\Users\lavan\AppData\Local\Temp\ipykernel_3648\4218787735.py:2: UserWarning:
# The palette list has fewer values (3) than needed (4) and will cycle, which may produce an uninterpretable plot.
#   sns.countplot(data=data, x='Timing', palette=custom_palette_timing)
# ([0, 1, 2, 3],
#  [Text(0, 0, 'Morning'),
#   Text(1, 0, 'Night'),
#   Text(2, 0, 'Afternoon'),
#   Text(3, 0, 'Evening')])

# %%
plt.tight_layout()
plt.show()

# %%
custom_palette_state = sns.color_palette("Set3", len(data['State'].unique()))
custom_palette_reason = sns.color_palette("Set2", len(data['Reason'].unique()))

# %%
plt.figure(figsize=(15, 10))

# %%
plt.subplot(2, 1, 1)
sns.countplot(data=data, y='State', order=data['State'].value_counts().index, palette=custom_palette_state)
plt.title('Accidents by State')
plt.xlabel('Number of Accidents')
plt.ylabel('State')
# Out:
# C:\Users\lavan\AppData\Local\Temp\ipykernel_3648\1566011937.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=data, y='State', order=data['State'].value_counts().index, palette=custom_palette_state)
# Text(0, 0.5, 'State')

# %%
plt.subplot(2, 1, 2)
sns.countplot(data=data, y='Reason', order=data['Reason'].value_counts().index, palette=custom_palette_reason)
plt.title('Accidents by Reason')
plt.xlabel('Number of Accidents')
plt.ylabel('Reason')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\lavan\AppData\Local\Temp\ipykernel_3648\304548987.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=data, y='Reason', order=data['Reason'].value_counts().index, palette=custom_palette_reason)
